# %%
#Import the basic necessary modules
import numpy as np
import pandas as pd


#importing ploting libraries
import matplotlib.pyplot as plt   

#importing seaborn for statistical plots
import seaborn as sns

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression

# %%
# location where the data is available
data_url = "https://raw.githubusercontent.com/GreatLearningAIML1/bangalore-aug19-batch-knightriderX/master/Project-2/DataSets/Bank_Personal_Loan_Modelling.csv?token=ABRYHI2UWQAOYUBZUVPAIMC5XP37U"

# %%
# load the data
customer_raw_data = pd.read_csv(data_url)

# %%
customer_raw_data.head()
# Out:
#    ID  Age  Experience  ...  CD Account  Online  CreditCard
# 0   1   25           1  ...           0       0           0
# 1   2   45          19  ...           0       0           0
# 2   3   39          15  ...           0       0           0
# 3   4   35           9  ...           0       0           0
# 4   5   35           8  ...           0       0           1
#
# [5 rows x 14 columns]

# %%
customer_raw_data.shape
# Out:
# (5000, 14)

# %%
customer_raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
# ID                    5000 non-null int64
# Age                   5000 non-null int64
# Experience            5000 non-null int64
# Income                5000 non-null int64
# ZIP Code              5000 non-null int64
# Family                5000 non-null int64
# CCAvg                 5000 non-null float64
# Education             5000 non-null int64
# Mortgage              5000 non-null int64
# Personal Loan         5000 non-null int64
# Securities Account    5000 non-null int64
# CD Account            5000 non-null int64
# Online                5000 non-null int64
# CreditCard            5000 non-null int64
# dtypes: float64(1), int64(13)
# memory usage: 547.0 KB

# %%
customer_raw_data.describe()
# Out:
#                 ID          Age  ...       Online   CreditCard
# count  5000.000000  5000.000000  ...  5000.000000  5000.000000
# mean   2500.500000    45.338400  ...     0.596800     0.294000
# std    1443.520003    11.463166  ...     0.490589     0.455637
# min       1.000000    23.000000  ...     0.000000     0.000000
# 25%    1250.750000    35.000000  ...     0.000000     0.000000
# 50%    2500.500000    45.000000  ...     1.000000     0.000000
# 75%    3750.250000    55.000000  ...     1.000000     1.000000
# max    5000.000000    67.000000  ...     1.000000     1.000000
#
# [8 rows x 14 columns]

# %%
customer_raw_data.describe().transpose()
# Out:
#                      count          mean  ...       75%      max
# ID                  5000.0   2500.500000  ...   3750.25   5000.0
# Age                 5000.0     45.338400  ...     55.00     67.0
# Experience          5000.0     20.104600  ...     30.00     43.0
# Income              5000.0     73.774200  ...     98.00    224.0
# ZIP Code            5000.0  93152.503000  ...  94608.00  96651.0
# Family              5000.0      2.396400  ...      3.00      4.0
# CCAvg               5000.0      1.937938  ...      2.50     10.0
# Education           5000.0      1.881000  ...      3.00      3.0
# Mortgage            5000.0     56.498800  ...    101.00    635.0
# Personal Loan       5000.0      0.096000  ...      0.00      1.0
# Securities Account  5000.0      0.104400  ...      0.00      1.0
# CD Account          5000.0      0.060400  ...      0.00      1.0
# Online              5000.0      0.596800  ...      1.00      1.0
# ...

# %%
#sns.countplot(x='Age',linewidth=1,palette=sns.color_palette("muted", 3),data=customer_raw_data,)
customer_raw_data['Age'].plot(kind='hist',legend=True)

# %%
customer_raw_data.corr()
sns.heatmap(customer_raw_data.corr(),)

# %% [markdown]
# Columns considered to be dropped:
# 1. ID
# 2.

# %%
sns.pairplot(data=customer_raw_data,hue='Personal Loan')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /usr/local/lib/python3.6/dist-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
# Target column distribution
customer_raw_data['Personal Loan'].plot(kind='hist',legend=True)

# %% [markdown]
# The target column - Personal Loan seems to be right skewed.

# %%
#customer_raw_data[ customer_raw_data['Personal Loan']==1].corr

# %% [markdown]
# what to do next

# %%
customer_raw_data[customer_raw_data.isnull()==True]
# Out:
#       ID  Age  Experience  ...  CD Account  Online  CreditCard
# 0    NaN  NaN         NaN  ...         NaN     NaN         NaN
# 1    NaN  NaN         NaN  ...         NaN     NaN         NaN
# 2    NaN  NaN         NaN  ...         NaN     NaN         NaN
# 3    NaN  NaN         NaN  ...         NaN     NaN         NaN
# 4    NaN  NaN         NaN  ...         NaN     NaN         NaN
# ...   ..  ...         ...  ...         ...     ...         ...
# 4995 NaN  NaN         NaN  ...         NaN     NaN         NaN
# 4996 NaN  NaN         NaN  ...         NaN     NaN         NaN
# 4997 NaN  NaN         NaN  ...         NaN     NaN         NaN
# 4998 NaN  NaN         NaN  ...         NaN     NaN         NaN
# 4999 NaN  NaN         NaN  ...         NaN     NaN         NaN
#
# [5000 rows x 14 columns]

# %% [markdown]
# Age : normally distributed mostly

# %%
customer_raw_data[ customer_raw_data['Personal Loan']==1]
# Out:
#         ID  Age  Experience  ...  CD Account  Online  CreditCard
# 9       10   34           9  ...           0       0           0
# 16      17   38          14  ...           0       0           0
# 18      19   46          21  ...           0       0           0
# 29      30   38          13  ...           1       1           1
# 38      39   42          18  ...           1       1           0
# ...    ...  ...         ...  ...         ...     ...         ...
# 4883  4884   38          13  ...           1       1           1
# 4927  4928   43          19  ...           1       1           1
# 4941  4942   28           4  ...           0       1           0
# 4962  4963   46          20  ...           1       1           1
# 4980  4981   29           5  ...           1       1           1
#
# [480 rows x 14 columns]

# %% [markdown]
# Data Cleansing:
# 1. Drop ID, ZIP Code
# 2. Change the negative Experience to positive

# %%
customer_data = customer_raw_data.drop(['ID','ZIP Code'],axis=1,)
customer_data.head()
# Out:
#    Age  Experience  Income  ...  CD Account  Online  CreditCard
# 0   25           1      49  ...           0       0           0
# 1   45          19      34  ...           0       0           0
# 2   39          15      11  ...           0       0           0
# 3   35           9     100  ...           0       0           0
# 4   35           8      45  ...           0       0           1
#
# [5 rows x 12 columns]

# %%
customer_data['Experience'].min()
# Out:
# -3

# %%
customer_data['NewExperience'] = customer_data['Experience'].apply(lambda x: x*-1 if x < 0 else x)

# %%
customer_data[customer_data['Experience']<0]
# Out:
#       Age  Experience  Income  ...  CreditCard  NewExperience  NewExperience2
# 89     25          -1     113  ...           1              1             1.0
# 226    24          -1      39  ...           0              1             1.0
# 315    24          -2      51  ...           0              2             2.0
# 451    28          -2      48  ...           0              2             2.0
# 524    24          -1      75  ...           0              1             1.0
# 536    25          -1      43  ...           0              1             1.0
# 540    25          -1     109  ...           0              1             1.0
# 576    25          -1      48  ...           1              1             1.0
# 583    24          -1      38  ...           0              1             1.0
# 597    24          -2     125  ...           1              2             2.0
# 649    25          -1      82  ...           0              1             1.0
# ...

# %%
customer_data_df = customer_data.drop( (customer_data[['Mortgage','Personal Loan','Securities Account','CD Account','Online','CreditCard']]==0).index, axis=0)

# %%
customer_data_df.shape
# Out:
# (0, 14)
