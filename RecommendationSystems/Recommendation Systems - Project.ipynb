# %% [markdown]
# # Recommendation System | Project | KG

# %%
import sys

import tensorflow.keras
import pandas as pd
import sklearn as sk
import tensorflow as tf

print(f"Tensor Flow Version: {tf.__version__}")
print(f"Keras Version: {tensorflow.keras.__version__}")
print()
print(f"Python {sys.version}")
print(f"Pandas {pd.__version__}")
print(f"Scikit-Learn {sk.__version__}")
gpu = len(tf.config.list_physical_devices('GPU'))>0
print("GPU is", "available" if gpu else "NOT AVAILABLE")
# Out:
# Tensor Flow Version: 2.1.0
# Keras Version: 2.2.4-tf
#
# Python 3.7.7 (default, May  6 2020, 11:45:54) [MSC v.1916 64 bit (AMD64)]
# Pandas 1.1.1
# Scikit-Learn 0.23.2
# GPU is available

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
rawdata = pd.read_csv("ratings_Electronics.csv", names = ['userID','prodID','rating','timeStamp'] )

# %%
rawdata.describe()
# Out:
#              rating     timeStamp
# count  7.824482e+06  7.824482e+06
# mean   4.012337e+00  1.338178e+09
# std    1.380910e+00  6.900426e+07
# min    1.000000e+00  9.127296e+08
# 25%    3.000000e+00  1.315354e+09
# 50%    5.000000e+00  1.361059e+09
# 75%    5.000000e+00  1.386115e+09
# max    5.000000e+00  1.406074e+09

# %%
rawdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7824482 entries, 0 to 7824481
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   userID     object
#  1   prodID     object
#  2   rating     float64
#  3   timeStamp  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 238.8+ MB

# %%
rawdata.drop(['timeStamp'], axis=1, inplace=True)

# %%
rawdata.isnull().sum()
# Out:
# userID    0
# prodID    0
# rating    0
# dtype: int64

# %% [markdown]
# There are no null values!

# %%
print("There are ", rawdata['userID'].nunique()," users who reviewed ", rawdata['prodID'].nunique(), " products")
# Out:
# There are  4201696  users who reviewed  476002  products

# %%
user_rating_counts = rawdata['userID'].value_counts()

# %%
user_rating_counts
# Out:
# A5JLAU2ARJ0BO     520
# ADLVFFE4VBT8      501
# A3OXHLG6DIBRW8    498
# A6FIAB28IS79      431
# A680RUE1FDO8B     406
#                  ...
# A30WC6JE6FBEBO      1
# A350YH5R3X0G5I      1
# A3QQ15T3HNRJBJ      1
# ARI9ZOEA34YE0       1
# A3BH4N97KHC615      1
# Name: userID, Length: 4201696, dtype: int64

# %%
workingData = rawdata[rawdata['userID'].isin(user_rating_counts[user_rating_counts > 50].index)]

# %%
workingData.shape
# Out:
# (122171, 3)

# %%
print("There are ", workingData['userID'].nunique()," users who reviewed ", workingData['prodID'].nunique(), " products")
print("The current overview in our working data set ")
# Out:
# There are  1466  users who reviewed  47155  products
# The current overview in our working data set

# %%
groupedUser = workingData.groupby('prodID')

# %%
popularProducts = groupedUser.agg({'userID':'count'})

# %%
popularProducts.rename(columns={'userID':'score'}, inplace=True)

# %%
popularProducts.reset_index()
popularProducts.head()
# Out:
#             score
# prodID
# 0594481813      1
# 0970407998      2
# 0972683275      3
# 1400501466      5
# 1400501520      1

# %%
topPopularProducts = popularProducts.sort_values(by='score', ascending=False)[:10]

# %% [markdown]
# However, in this case, popular products does not necessarily mean highly rated products, but most reviewed products.

# %%
topPopularProducts
# Out:
#             score
# prodID
# B0088CJT4U    204
# B003ES5ZUU    177
# B000N99BBC    163
# B007WTAJTO    156
# B00829TIEK    146
# B008DWCRQW    135
# B00829THK0    132
# B002R5AM7C    127
# B004CLYEDC    117
# B004T9RR6I    108

# %% [markdown]
# ## Train test split

# %%
from sklearn.model_selection import train_test_split

# %%
# from surprise.model_selection import train_test_split

# %%
trainData, testData = train_test_split(workingData, test_size = 0.3, random_state = 0)


print(trainData.info())
print()
print(testData.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85519 entries, 1374364 to 4178710
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   userID  85519 non-null  object
#  1   prodID  85519 non-null  object
#  2   rating  85519 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 2.6+ MB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36652 entries, 7799371 to 4091526
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   userID  36652 non-null  object
#  1   prodID  36652 non-null  object
#  2   rating  36652 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 1.1+ MB
# None

# %% [markdown]
# # Collaborative Filtering

# %%
from surprise import Reader, Dataset

from surprise import KNNBasic, KNNBaseline, KNNWithZScore, KNNWithMeans, NormalPredictor, SVD, SVDpp, NMF, SlopeOne, CoClustering, BaselineOnly

from surprise.model_selection import cross_validate

# %%
r = Reader(rating_scale=(1,5))
#d = Dataset.load_from_df(trainData, r)
d = Dataset.load_from_df(workingData, r)

# %%
bm = []

algos = [KNNBasic(), KNNBaseline(), KNNWithZScore(), KNNWithMeans(), NormalPredictor(), SVD(), SVDpp(), NMF(), SlopeOne(), CoClustering(), BaselineOnly() ]

for algo in algos:

    results = cross_validate(algo, d, measures = ['RMSE'], cv = 2, verbose = False)
    output = pd.DataFrame.from_dict(results).mean(axis = 0)
    output = output.append(pd.Series([str(algo).split(' ')[0].split('.')[-1]], index=['Algorithm']))
    bm.append(output)

pd.DataFrame(bm).set_index('Algorithm').sort_values('test_rmse')
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Estimating biases using als...
# Estimating biases using als...
#                  test_rmse   fit_time  test_time
# Algorithm
# BaselineOnly      0.985082   0.323106   0.516501
# SVD               0.987144   5.607271   0.738349
# SVDpp             0.988322  73.310576   5.607432
# KNNBaseline       1.043523   0.433004   1.795501
# KNNWithMeans      1.066131   0.183502   1.585498
# KNNWithZScore     1.070207   0.290001   1.924999
# CoClustering      1.090862   7.004556   0.519003
# SlopeOne          1.096300  41.289502   3.062246
# KNNBasic          1.113432   0.123174   1.703263
# NMF               1.154593  10.694884   0.696503
# NormalPredictor   1.368392   0.154999   1.014001

# %%
from surprise.model_selection import train_test_split

# %%
trainset, testset = train_test_split(d, test_size=0.3,random_state=20)

# %%
# baselineOnly_options = {'method': 'als', 'n_epochs': 5, 'reg_u': 12, 'reg_i': 5 }
# algo = BaselineOnly(bsl_options=baselineOnly_options)
# cross_validate(algo, trainset, measures=['RMSE'], cv=3, verbose=False)
# Out:
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# {'test_rmse': array([0.9848268 , 0.99080434, 0.97784835]),
#  'fit_time': (0.16100215911865234, 0.1750044822692871, 0.1979992389678955),
#  'test_time': (0.22900032997131348, 0.2559995651245117, 0.26599979400634766)}

# %%
# algos

# %%
# d

# %%
for algo in algos:
    algo.fit(trainset)
    test_predictions = algo.test(testset)
    print(algo.__class__.__name__, " Test Prediction accuracy ", accuracy.rmse(test_predictions, verbose=True))
    print()
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.1086
# KNNBasic  Test Prediction accuracy  1.1085573112306182
# Estimating biases using als...
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0415
# KNNBaseline  Test Prediction accuracy  1.0415018537731429
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0635
# KNNWithZScore  Test Prediction accuracy  1.063501937599031
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.0614
# KNNWithMeans  Test Prediction accuracy  1.0614354113224311
# RMSE: 1.3601
# NormalPredictor  Test Prediction accuracy  1.3601235941053618
# RMSE: 0.9870
# SVD  Test Prediction accuracy  0.9869895676314099
# RMSE: 0.9875
# SVDpp  Test Prediction accuracy  0.9874588556161215
# RMSE: 1.1455
# NMF  Test Prediction accuracy  1.1454994942441592
# RMSE: 1.0946
# SlopeOne  Test Prediction accuracy  1.0946289557606204
# RMSE: 1.0762
# CoClustering  Test Prediction accuracy  1.0762320152542655
# Estimating biases using als...
# RMSE: 0.9827
# BaselineOnly  Test Prediction accuracy  0.9826731408452305

# %% [markdown]
# ## *NormalPredictor seems to have better test prediction accuracy over the rest*

# %% [markdown]
# ### code below obtained from https://surprise.readthedocs.io/en/stable/FAQ.html How to get the top-N recommendations for each user

# %%
from collections import defaultdict

# %%
def get_top_n(predictions, n=10):
    """Return the top-N recommendation for each user from a set of predictions.

    Args:
        predictions(list of Prediction objects): The list of predictions, as
            returned by the test method of an algorithm.
        n(int): The number of recommendation to output for each user. Default
            is 10.

    Returns:
    A dict where keys are user (raw) ids and values are lists of tuples:
        [(raw item id, rating estimation), ...] of size n.
    """

    # First map the predictions to each user.
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Then sort the predictions for each user and retrieve the k highest ones.
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n

# %%
top_n = get_top_n(test_predictions, n=5)

# %%
for uid, user_ratings in top_n.items():
    print(uid, [iid for (iid, _) in user_ratings])
# Out:
# PZQYE6', 'B003TM3EL8']
# A15Q2L6DYRTFIU ['B004UQ05M8', 'B00483WRZ6', 'B00394T7BW', 'B001HJTK5Y', 'B00GUQJZCW']
# A2PC9ZZIFV31B1 ['B007WTAJTO', 'B0044YPN0A', 'B008SFPMRK', 'B004L3R0Z0', 'B004I43F9C']
# A3NXJDNTQK2YJL ['B0052SCU8U', 'B000IJY8DS', 'B0082E9K7U', 'B00005T3G0', 'B003M0NURK']
# A3TR3KLL5PXSZ8 ['B004AZ38Z0', 'B001GCU0MY', 'B0000ZJDXU', 'B004XY65WQ', 'B00AO0K3KS']
# A3BI8BKIHESDNQ ['B000FBK3QK', 'B0009ON12G', 'B0003NN83K', 'B0057XC2X8', 'B007P4VOWC']
# A11LNPG39A2ZV4 ['B00BOHNYU6', 'B00BOHNYTW', 'B0041OSAZ8', 'B001KUL012', 'B000LRMS66']
# AFFVUZEGP1FDQ ['B004HKJTT2', 'B001TH7GT6', 'B00FJWKYYG', 'B00IX2VGFA', 'B000BSOBG0']
# A3GQY0TFRG0MPZ ['B008JCVF0U', 'B001XURP7W', 'B009FD4UDG', 'B007I5BRIE', 'B003V42O6K']
# A1143YEAZYMYHJ ['B0002L5R78', 'B001FA1NZK', 'B00894YP00', 'B001EYV9TM', 'B00HR7FWUC']
# A3AGQAXTX6VRJ3 ['B0019EHU8G', 'B0007QKMQY', 'B007WTAJTO', 'B0001CNMFM', 'B003ZUIHY8']
# AELK0E5DK7LIZ ['B00BOHNYU6', 'B00829THK0', 'B00005N5WW', 'B000GINMOW', 'B00007FS0F']
# AZCE11PSTCH1L ['B003W9B4H4', 'B008X1C1DC', 'B003TY9SES', 'B000JJM8XE', 'B0094NXBZ0']
# AWNBZSEZ9P8BE ['B00HVT27B8', 'B00DMS0GTC', 'B004DYQRME', 'B003M0NURK', 'B009SQQF9C']
# AGJRUK27RBVYS ['B00FZ9SMVU', 'B00G6IJ5NI', 'B005PUZOYM', 'B00BP5KOPA', 'B00C18YUW8']
# A3VBZDYGHF4NK8 ['B003ES5ZUU', 'B00FZ9SMVU', 'B00CD778LC', 'B00BWHILCY', 'B002I3OZ6W']
# A32AK8FOAZEPE2 ['B004LNXO28', 'B002QEBMAK', 'B002RM08RE', 'B001XURP7W', 'B001U3YIT0']
# A2OTQMC69J8MUI ['B007WTAJTO', 'B00ATM1MHO', 'B009D79VH4', 'B005LFT3GG', 'B000UXDHOI']
# AFH97KY1SBP2C ['B003Y2WUIQ', 'B001AZV2WY', 'B002WH3QLE', 'B000R5LWRI', 'B00159RFLM']
# A12LH2100CKQO ['B0058UUR6E', 'B00007IFED', 'B003BLQHN4', 'B000067SPL', 'B00005AC8W']
# A2VC48WIMY6L6E ['B003ES5ZUU', 'B001E3XLZS', 'B00DUN2PBQ', 'B00EFILHB4', 'B000S95RWE']
# A2I357I10ZY7CI ['B0034CL2ZI', 'B004S76NH0', 'B003LL1EM8', 'B00B8L36A6', 'B00494XZ1Y']
# A2J96FILPQA01 ['B004XC6GJ0', 'B00108UNEY', 'B008C1JC4O', 'B00FCMV8ES', 'B0061RJSWC']
# A3NGOG8Z78AZSD ['B004WK3U9W', 'B00IUICOF8', 'B00002EQCW', 'B00028VKLI', 'B004BP03YI']
# A16HXVNPU5TCGE ['B003LVZO92', 'B000YB862E', 'B003ANK9ZA', 'B00162YZXE', 'B004N627KS']
# A4UGMKUSX9XHI ['B000N99BBC', 'B00COF7DGS', 'B00E7LSCNK', 'B00009R6WT', 'B002ZCXJZE']
# A31RZMVAFMLB8B ['B00017LSPI', 'B00AAIPT76', 'B001KBZ3SC', 'B001IMPVEE', 'B0029LDIS4']
# A2KIJBT9HRIOM8 ['B004WB8EYM', 'B000FFISV8', 'B002ROILDA', 'B0049S2ZZM', 'B0030MIU16']
# A5MCDQ60DWUEV ['B002WE6D44', 'B008EQYRRY', 'B0056TYRMW', 'B0048IW030', 'B0000A1G05']
# A3N4I2KRSMACW8 ['B005J2E2US', 'B0011UIXLG', 'B001X017G2', 'B001BX6HCU', 'B00A203I0W']
# ANTGGAQYPSWHF ['B001FWYXD2', 'B00005AC8W', 'B00004TRD9', 'B008HK3WK0', 'B000V5G4TK']
# A2XHOLOLKGV1FE ['B001F7AHOG', 'B0001GMIOE', 'B00429N18S', 'B002ZCXJZE', 'B004U7UAWM']
# A19NP8YYADOOSF ['B0017H4G0A', 'B003IRR0YQ', 'B005A2RLXC', 'B005GI19HY', 'B003RAE19Q']
# AN9WA4C5E7YY5 ['B00AANQLRI', 'B000E9VKUQ', 'B00746LVOM', 'B004CANMCC', 'B001A9ST2G']
# A2Y1WNETD9AYHO ['B007PRHNHO', 'B001EAQTRI', 'B000OFWJO6', 'B002SKAP46', 'B007EHWHZS']
# A34DQINHT6NYJU ['B00D6XW62I', 'B0043M668G', 'B0079UAT0A', 'B005O9YMM4', 'B00475K64E']
# A20WUUD9EDWY4N ['B0012Y2LLE', 'B005LFT3GG', 'B00004ZC8Y', 'B00BI9X7UC', 'B002BZFSYA']
# AJL3U764D7NI3 ['B001TH7T2U', 'B0002LEMWE', 'B002G1YPH0', 'B007SZ0E1K', 'B000CKVOOY']
# A19HT7YC1UW3D6 ['B002WE6D44', 'B004V4IWHY', 'B000FBK3QK', 'B000LGFLXO', 'B006JH8T3S']
# A2BIJMB2BITQUM ['B004CLYE8C', 'B004Q3R9AQ', 'B00AAIPT76', 'B00HFRWWAM', 'B00829THEG']
# A32LX4XJ2LU740 ['B00006B9CR', 'B007PRHNHO', 'B004B8GF7Y', 'B008TLQ5RY', 'B005GTNZUM']
# A2H4OMJLE7JFM2 ['B0012Y2LLE', 'B002M3SOCE', 'B000FIDTYG', 'B005FYNSPK', 'B000CSOXTO']
# A3D5B2CBFNJB0K ['B00F0DD0I6', 'B00FRMAOIO', 'B007PTCFFW', 'B00K91DB7Y', 'B004CW9KEO']
# A2IFGGXG3YV3Y6 ['B00D5Q75RC', 'B008OEHPKM', 'B00AAHT8JC', 'B005PUZOYM', 'B003YL412A']
# A105TOJ6LTVMBG ['B004W2JKWG', 'B00182CIB8', 'B000Q8UAWY', 'B004IZN3WK', 'B0019WF4FE']
# A1UL2JH7XOUGM5 ['B0041L3JS4', 'B00BQ8TZSI', 'B0076BNKU8', 'B0049RLM3O', 'B00CO2D4G4']
# A2AC6GQ24S45GA ['B00IVFDZBC', 'B004CLYEFK', 'B00DT04I9W', 'B00829THK0', 'B008U3038I']
# A1CN1P7147QDJC ['B006QB1RPY', 'B0010YWPZ8', 'B003WUBIZQ', 'B00CGUMR2Q', 'B0041G633W']
# A3QU3O79AGNWCY ['B001IEZX3G', 'B002VPDM2A', 'B006ZBWV0K', 'B009WE65EA', 'B000E5CYW8']
# A16RI68PS6T5CA ['B00BCA41PW', 'B000M2GYF6', 'B00829THVO', 'B009WG6JF8', 'B0002TA96Y']
# A3TCMJ6GKZJFBQ ['B001BM5XB2', 'B00COF7DGS', 'B00119T6NQ', 'B0034CL2ZI', 'B002NEGTSI']
# A196JN53PG0C7R ['B001TH7GUA', 'B001C271MA', 'B001NJ0D0Y', 'B000V06UHQ', 'B00119NBEG']
# A2Q2A6JKY95RTP ['B003ES5ZUU', 'B0015AARJI', 'B002QUZM0U', 'B00AVWKUXE', 'B00DQZP7X6']
# A3IJL9A50KVVZ1 ['B00068YUN4', 'B00AO1XFM0', 'B005Z1E3IY', 'B0074024XU', 'B003DZ165W']
# A1ZVFCPHCWFV71 ['B0076MBOC8', 'B008MF3X9K', 'B00740MR78', 'B0056YNA2A', 'B000N254LU']
# A1KWPIORLG2QV ['B0012IJYZQ', 'B00519RW1U', 'B00A81SXHI', 'B0038L495U', 'B002RWJGTU']
# A1C5WS021EL3WO ['B001TH7T2U', 'B000CRFOMK', 'B004C3AW40', 'B0002Y5WZM', 'B003XM9774']
# A3LDLV1GWQJLEQ ['B00829TIEK', 'B00F3F0EIU', 'B00CO1I29O', 'B00IODWU6W', 'B00006HQ4D']
# A2JXS1JII6SAUD ['B007SZ0EHE', 'B009HP42HQ', 'B008V9959O', 'B00CCEH51Y', 'B0046HUIFA']
# A2QI2JHSIQ3SN3 ['B006U3O566', 'B002IO2UM2', 'B0006I1TRY', 'B001078FV8', 'B0055193D4']
# A3LDPF5FMB782Z ['B001FA09WI', 'B000VL1QF6', 'B0030NL6FW', 'B002W4RPD2', 'B0044R1VY4']
# A11IXJ8M1JO296 ['B000QUUFRW', 'B004LSNF04', 'B008OHNZI0', 'B004PVW1DE', 'B0012S4APK']
# A2X78O6G89CB30 ['B000J1H4VI', 'B0090BSSZO', 'B000Q8UAWY', 'B000RFR696', 'B00032Q30Q']
# ASFP250F22MDZ ['B005FDXF2C', 'B00834SJNA', 'B002HWRJBM', 'B001H8DF0G', 'B000AAZQJU']
# A2QI2NTDTMK2FV ['B004GF8TIK', 'B002UVNW5W', 'B000KJQ1DG', 'B001EYV9TM', 'B0001GRTK2']
# A2ZDY0V4Q1SZD7 ['B003ES5ZUU', 'B001TH7GUU', 'B000VX6XL6', 'B004C9P9TM', 'B007DJGHF8']
# A2SGAJWXG65464 ['B005T3GPXE', 'B007HBLX8I', 'B005U0M9B8', 'B00C94GTJQ', 'B0030DL37I']
# A2HBOG4LVIY15L ['B008JJLW4M', 'B002WE6D44', 'B00834SJSK', 'B005J7YA4G', 'B001N9X4CS']
# A2E1EFNIZL2FVA ['B00834SJSK', 'B002TLTE6O', 'B003VAHYNC', 'B00AAKLFHM', 'B00JC5Y6YA']
# A2Y739CRM15WDL ['B00119T6NQ', 'B00829THK0', 'B0016BVKAQ', 'B00E8CF0CE', 'B00834SJNA']
# A3KCKECEO3E2AN ['B00CGYCOR0', 'B002MCZJ78', 'B002C1BHIO', 'B00F1CRTJM', 'B004GUT1QO']
# A6XDZ1MJ0B1A2 ['B006QB1RPY', 'B002MAPRYU', 'B003N8GVUY', 'B008RM235I', 'B002XW44QY']
# A3QNX5KWHDV0GD ['B000BY52NK', 'B001A4HAFS', 'B001IOPIRM', 'B00007EDZG', 'B00065AO0K']
# A2A4X545ERLS7H ['B00006HSYC', 'B00CPGYNV4', 'B008LTBITY', 'B0040QE97A', 'B0040QE998']
# A3JU16JTNLVK1J ['B000IJY8DS', 'B004TJ6JH6', 'B0002Y5WZC', 'B000WL6YY8', 'B001D5FTE8']
# AM8W6Y3HVXLZT ['B000JMJWV2', 'B002YU83YO', 'B0002IWC9C', 'B008RW6R9Q', 'B000MUXJCO']
# AGX2K0FMS0IVL ['B002YU83YO', 'B001AHALEC', 'B0000AUR23', 'B006FGKUUI', 'B007Q2M17K']
# ARW8VGT10JG60 ['B007QOX5A0', 'B0040JHVC2', 'B005IHAIC0', 'B003CJTQJC', 'B001MSVPM6']
# A1ROUMJOGO4QMB ['B002M3SOBU', 'B00385XUG0', 'B00629NHW6', 'B00224ZDFY', 'B003ZKG10K']
# AOVTLYTHVDNUX ['B003ZUM5LE', 'B00HMREOLK', 'B001WM73P0', 'B00HSGFPC2', 'B0019CGBHO']
# AENULRBQ2IE5I ['B002ZIMEMW', 'B003AVMRQG', 'B0018O9JIG', 'B0041Q38NU', 'B00006JPWW']
# AN2IZT80ZUNJN ['B004TJ6JH6', 'B004VD7V54', 'B003YH2GH6', 'B0054EIGUI', 'B003YO2AJS']
# A1VRANSQ0WF1YS ['B0007A1IRC', 'B00007E7JU', 'B00114162K', 'B002YK1FFI', 'B0000AZK4G']
# A13WOT3RSXKRD5 ['B000QWEN5K', 'B001207YMY', 'B004CAHTCQ', 'B00829TIA4', 'B007NZGPAY']
# A2SPV96SGOEO2 ['B008EQYRRY', 'B00BP5KOPA', 'B008THTWIW', 'B000JE7GPY', 'B001A4LVYY']
# A1A306IAZ3TM1 ['B00009EHJV', 'B00762YNMG', 'B002DUD36S', 'B002BDUAEK', 'B000I5JMYW']
# A267FU71Z01CIH ['B00EOI2SR2', 'B00DOWCQB2', 'B008HO9DK4', 'B008X9ZD5C', 'B000NLSGA2']
# AO09RWV40IX78 ['B00BOHNYU6', 'B00F1CRTLK', 'B002GU5XKO', 'B005DKZTMG', 'B00F6E8OUS']
# A1UCAVBNJUZMPR ['B0018MEBNG', 'B004ALXSTU', 'B0017JY5FE', 'B007Z419BI', 'B008AGUFL0']
# A31HE83MU98GBV ['B003HIXOOG', 'B000F9YN22', 'B00C8OCEC8', 'B002LLJJAS', 'B000HSEEUM']
# A1TR1R2QKWRSRA ['B004CLYEDC', 'B0034CL2ZI', 'B0036R9YA6', 'B000SBCA7C', 'B005I6EU48']
# A2TRXEZYU9GYY8 ['B004G6002M', 'B00193U3O0', 'B0041NFIBS', 'B006IKH0EA', 'B005CT56F8']
# A356RFKNIG043B ['B003VAHYNC', 'B004VM1T5S', 'B00001P4ZH', 'B002XITTS6', 'B0043EV20Q']
# A10X9ME6R66JDX ['B0012GK3MQ', 'B007PRHNHO', 'B003XIJ3MW', 'B000IZDN60', 'B000RHV46U']
# A2D0CO1OA6DSWY ['B009SYZ8OC', 'B00AHBKW2S', 'B008OHNZI0', 'B00020S7XK', 'B002DPUUKK']
# AQSV34W54L0VO ['B000OGX5AM', 'B00E3W15P0', 'B00AAIPT76', 'B00A6P0EBO', 'B00AAIE01W']
# A1H55L0BLPCWYF ['B0002L5R78', 'B0046TJG1U', 'B003HFCDLY', 'B003JZU8DC', 'B005HXFARS']
# A3TBMGNSEQBWIL ['B000067RC4', 'B004CADY9I', 'B0059M4G9K', 'B003NVMHM2', 'B0042A2V88']
# A2X61KKXXR6WNP ['B005KQ2O26', 'B0000AKVHF', 'B000IZDN60', 'B001DJ64C0', 'B000FITKK8']
# A1FDSZISWIXH1A ['B004CLYEFK', 'B00AAHT8JC', 'B00L2442H0', 'B00310PJM0', 'B0013FRNKG']
# A3CJOB7CHOSZUG ['B002WE4HE2', 'B002VPE1Q6', 'B003M0NURK', 'B005SYQBN8', 'B000BN0TRK']
# A3AG5QAT8L0I3R ['B0058SRNZ4', 'B007LLYAIO', 'B00CRGJDD0', 'B007SHJIO2', 'B00CRFK24K']
# AYLLSFYS3UP1H ['B001F7AHOG', 'B0043RS864', 'B002ODIE54', 'B00AQ2BTHK', 'B000NP46K2']
# A1WF4QNIE2Z3I7 ['B005ES0YYA', 'B009NB8WR0', 'B0099SMFVQ', 'B009O7YUF6', 'B00009UT9B']
# A2XQYE6TJYROHQ ['B000HDJT4S', 'B000BONJXU', 'B003MQO96U', 'B001DL8WIC', 'B001DL4YMA']
# A2L4W1M5YU5QX3 ['B001TH7GUU', 'B001NS828K', 'B000JJSQ30', 'B002ZAVVHY', 'B000068O5H']
# A2NOIWPJDD7WIQ ['B000HJPK2C', 'B000HGIWN4', 'B00AHBKW2S', 'B00685ZCZY', 'B000BYCKU8']
# A12O5SEIF162P8 ['B009NHWVIA', 'B000CRFOMK', 'B00B1862X4', 'B0064EL2DK', 'B00HV6KGNM']
# A4H4KYSM2KQ85 ['B002V8C3W2', 'B005D5M122', 'B00IVPU786', 'B008LCYIEI', 'B002JCSV8A']
# A2RIXSMGE9VIBG ['B005UA3I72', 'B009NHAEXE', 'B000FBK3QK', 'B0088PUEPK', 'B0010QPX4G']
# A3F9CBHV4OHFBS ['B0012Y6HC8', 'B001TUYTZM', 'B0040JHVC2', 'B005EOWBKE', '9983891212']
# A3UKWQS8SRW6IO ['B00AYB3OMG', 'B001CROHX6', 'B000M5VXVS', 'B007YKUWN4', 'B0038JECKY']
# A2HV76MYH7UL3S ['B006VCP72W', 'B003D3MFHC', 'B008NGEARC', 'B007V5A1BK', 'B00D601UC8']
# A1WXG10FJ353K0 ['B00IVFDZBC', 'B001DJ64D4', 'B000M17AVO', 'B0090IA4FO', 'B0090Z3QG6']
# ASF3J4UYV34KA ['B001TH7GT6', 'B000UE8JWM', 'B0094D8UGU', 'B0050GDOUW', 'B001R4BBL0']
# A1JBEKU5TYIWE7 ['B006MRAVFE', 'B000IMSK8Y', 'B001T6K7G6', 'B00561CGIC', 'B003LYTXPK']
# A2N75ADJSRW0AH ['B000VUIXOO', 'B001KBZ3QO', 'B003VS9UP4', 'B003M0NURK', 'B002S9KTAW']
# A3775OP5VTX5ON ['B000JMJWV2', 'B00001W0DI', 'B000WOIFO2', 'B00006484F', 'B003B20F54']
# ANXEW7IDYDJEH ['B00006JN3G', 'B00BERGFV6', 'B000EVSLRO', 'B000L9OIQC', 'B004SBI2PW']
# A1XK4VP74IB9TQ ['B001F7AHOG', 'B004HO58SO', 'B0039825LM', 'B000B60H0G', 'B00452YFZU']
# A36MP37DITBU6F ['B004CLYEDC', 'B00D6XSRL2', 'B000QWEN5K', 'B004XVN17G', 'B004CLYEH8']
# A5CDMTW6JKV5G ['B0019EHU8G', 'B00BOHNYU6', 'B00A9NE84C', 'B001UEBN42', 'B0024FACAW']
# A34CSXOGVYF94S ['B004ELA0SS', 'B00HG1L334', 'B0082E9K7U', 'B00ISFNSBW', 'B00F0DD0I6']
# A21Q9JVG4SII51 ['B003MTTJOY', 'B006EKIQYM', 'B005UBNLFK', 'B009VV56TY', 'B0087B6SV4']
# A2I5LVVQ7WXEH6 ['B001TH7GVE', 'B00EN27SHY', 'B000JE7GPY', 'B00H09BOXQ', 'B000V1LX4K']
# AYP0YPLSP9ISM ['B001TH7GSW', 'B007PJ4PKK', 'B006Z0Q2SI', 'B004NY9UV4', 'B0052OZZYK']
# A1Q5P5ML3176C0 ['B0015L0T68', 'B0069K42HC', 'B003IA9HR6', 'B007VE0MFG', 'B006UMMPGE']
# A3D822N1K2IAQD ['B009YT6PPC', 'B00G5RDU5O', 'B00E055H5O', 'B0062MXHCS', 'B006JH8T3S']
# A365PBEOWM7EI7 ['B00829THO6', 'B001RNOHDU', 'B006T9B6R2', 'B000IV6S9S', 'B005TJ5CEG']
# A1CMWB7AWQUQH4 ['B001E1Y5O6', 'B009H0XQPU', 'B00728Z9JA', 'B005HMKKH4', 'B00213KDQK']
# A32O98PFC3OP7K ['B004TS2AP2', 'B003DTLV8K', 'B00GHY5F3K', 'B0035FZ142', 'B003LSTD42']
# A18A5VSD0IPN14 ['B0019EHU8G', 'B00AJHDZSI', 'B00358PRCA', 'B0041MY32Y', 'B003GSCS3U']
# A3QNQQKJTL76H0 ['B00BOHNYU6', 'B00DT04I9W', 'B002GP7ZT6', 'B002TMRZOQ', 'B00829TIA4']
# AQR4HPVSOPS08 ['B003ES5ZUU', 'B001TOD7ME', 'B003ES5ZR8', 'B003FVVMS0', 'B004CAHTCQ']
# A1SC5OXLQNGPLN ['B00007GQLU', 'B000LWJ1ES', 'B002JCSV8A', 'B007I5JT4S', 'B003HLSMNG']
# A2YYHSORXIHZCS ['B000VE2RP6', 'B003VKTJGW', 'B005SEZBXY', 'B005H3Q59U', 'B000EDI406']
# A1J5HIF41ENSMZ ['B00HFRWWAM', 'B005H3I38Q', 'B005FYNSPK', 'B00629NHW6', 'B00BAJ1QDA']
# A2I18AO597DSDI ['B00GO4GMAI', 'B007LLYB4M', 'B00B99JU5M', 'B0032ANC5U', 'B00EWEHIE6']
# A2BX8DDQGCCG2J ['B0097BEF1S', 'B004BLIQDC', 'B00746W3HG', 'B00E0EY7Z6', 'B002QQ8H8I']
# A2MSBIA18RXYQC ['B005INZKKE', 'B00JLADOGW', 'B000GKN3OE', 'B00171U8N0', 'B000P1711K']
# A1Y85GQ09Y95JL ['B005UA3I72', 'B00B4GGW5Q', 'B000CKVOOY', 'B000F9YN22', 'B009D79VH4']
# A1VLE2SH9J8WYS ['B0011U65F2', 'B008OHNZI0', 'B0019WF4FE', 'B000RQSGYO', 'B0007M0VWS']
# A11ED8O95W2103 ['B000H0K8VY', 'B001EQ4C8U', 'B000BGZMY2', 'B000BYJFYW', 'B0007XHLXO']
# A1XXMNLOLKNO0I ['B001TOD7ME', 'B007WTAJTO', 'B000053HC5', 'B0000C4G78', 'B004FPIO18']
# A3MU9G6YWKTGTA ['B00483WRZ6', 'B00007M1TZ', 'B00119NBEG', 'B001QUA6R0', 'B006U1YUW2']
# A362FM6FYA1SYS ['B000UMX7FI', 'B00E3W15P0', 'B007SZ0E1K', 'B0000A1G05', 'B00007EDZG']
# A3RR2P5IS3DGPR ['B004CLYEFK', 'B00BOHNYTW', 'B00IVPU786', 'B00008W2LC', 'B00DR8LA60']
# AJCR7L4AXL2OG ['B000MVJ1M0', 'B001QTXKF6', 'B001IQ7QAC', 'B002FRV1QS', 'B006ZN4SDG']
# AW3LX47IHPFRL ['B006YLTLUY', 'B002JPITXY', 'B001EH8FZA', 'B008RK9XTO', 'B008DZ2YT4']
# A3QKIR8J56EUI1 ['B005CWHZP4', 'B003WO7MZC', 'B005IHAIJ8', 'B003OBUJIK', 'B004APRLTY']
# A35W3JQYP0M655 ['B00ENZRS76', 'B007PJ4P4G', 'B00E3FHXYO', 'B00G500AE0', 'B007OY5V68']
# AWJWCKB92RJX2 ['B00429N18S', 'B0015AB3HI', 'B0019I1K0G', 'B000EEQ83K', 'B000U5TUWE']
# AKSQNMIKOU01H ['B0000WKYU4', 'B0019CSVMW', 'B002SXMRW6', 'B0032BH46M', 'B001AHALEC']
# A1VQBEW0G4IH1J ['B004CLYEFK', 'B0096W1OCG', 'B00EOE4G4E', 'B003M8HWDA', 'B004YHXXKO']
# A26BDXG9KVH7SU ['B009NHWVIA', 'B00966PFHW', 'B00C8OCEC8', 'B008MWBY6W', 'B007LLYB4M']
# A3KZEGBTPH6MMF ['B00DR6DQZA', 'B007PJ4PKK', 'B002RWJHBM', 'B004YLCBRG', 'B005A2RLXC']
# A1VGXHHR08G044 ['B00CKAOJA0', 'B00GK22DF2', 'B0088PUEPK', 'B00486UR2I', 'B00834SJNA']
# A3S5WYWYKSAI9C ['B00D6XW62I', 'B00CKAOJA0', 'B004CLYJ0K', 'B00B99JU5M', 'B005X64MOG']
# AFM2J3HJNPIHV ['B007WTAJTO', 'B00006RVPW', 'B008DWYBZM', 'B009W34X5O', 'B0040PZ3EE']
# A2WYF4POBUXL2O ['B001BTCSI6', 'B00009UTL1', 'B001BTG3OQ', 'B001KJ91V4', 'B004JZI78O']
# AATWFX0ZZSE6C ['B002Y6CJJ8', 'B003C1FC7K', 'B0041Q38NU', 'B002RYYZZS', 'B000CSWCQA']
# A1V5TRJXTI6F01 ['B002FB684E', 'B00A83I8G2', 'B008GVL9YQ', 'B0037H8AB4', 'B001UGMTKC']
# AU3GYRAKBUAEU ['B004SBBD1C', 'B000F34FVM', 'B005OOKNP4', 'B0056C4VRK', 'B00D8X0IJ4']
# A9ELHLPXF7JKD ['B0034CL2ZI', 'B002MAPRYU', 'B004GUT1QO', 'B00698WP50', 'B0064X5Q5Q']
# AUUV3XDYB16X5 ['B00E3W15P0', 'B0079M711S', 'B003TR1OEC', 'B001BRP0UG', 'B00004TWM0']
# A38Z6QG6988WS7 ['B002SQKL7Q', 'B005VFG06W', 'B001F6YRNO', 'B008I64126', 'B009EADB2Q']
# A2POXR5VS3PHKR ['B001TH7GSW', 'B000VR3P9K', 'B000BRFE4O', 'B003JTHN2C', 'B0041OODRM']
# A38CHSS1ZAE51B ['B001TH7GUU', 'B0046TJG1U', 'B001F7AJKI', 'B001JYVFLY', 'B000UO6C5S']
# A1VYFEJM12ZP11 ['B007WTAJTO', 'B00IF4OATU', 'B000SMVQK8', 'B001TZQITM', 'B008X9Z44M']
# A11ULAZ4B5ZXC8 ['B000IJY8DS', 'B000CKVOOY', 'B000N99BBC', 'B00DR0RBV6', 'B003ZWN7DW']
# A1PSVZBM894R5H ['B000RZQZM0', 'B0007GIXS8', 'B003M2YT96', 'B00000JMRX', 'B0009MFQ1M']
# AOJA1LC8PN7K1 ['B000N99BBC', 'B00030DEQE', 'B00D1GYNT4', 'B000UCAQ1G', 'B0009JO2YC']
# A1OA2ZW406NQXM ['B007PJ4P4G', 'B001UE8IMC', 'B004BQTTE2', 'B000NLLXVQ', 'B001287F4S']
# AO2EURP2Y4JZM ['B001C271MA', 'B00IVPU59W', 'B0088PUEPK', 'B00009R6TA', 'B002ZCXJZE']
# A2V0I904FH7ABY ['B0002ZAIM8', 'B001TZWNF0', 'B00007M1TZ', 'B00126R3P6', 'B001NPEB5Q']
# A1TY97ZGQT5FGF ['B001AI6CNK', 'B0036QF0BE', 'B000SEN9U6', 'B005DMZKZA', 'B0044EOQO4']
# A2UEB48LAWFUCW ['B00IVPU59W', 'B003LVZO88', 'B00005LB8P', 'B00GHY5F3K', 'B0017JY5FE']
# A3V15SFD7918WZ ['B004CLYEFK', 'B00829THO6', 'B001OI2Z4Q', 'B00CRY250U', 'B00GY0UFFA']
# A3977M5S0GIG5H ['B004TJ6JH6', 'B003ZUIHY8', 'B00000K4KH', 'B00GNGCX6O', 'B0041EL7JY']
# AS7J4952JB5XR ['B000S5Q9CA', 'B00FPKDPZC', 'B00ATM1MHO', 'B0092KRAVQ', 'B00009UTDL']
# A2FHTXLKY1XJDB ['B009LL9VDG', 'B001OXKPDO', 'B00G6BQ31W', 'B000I8FZQI', 'B00F4PRKDG']
# A7KBAXO177NND ['B004V4IWHY', 'B00006I5J7', 'B001WB02Z4', 'B003ZYF3M8', 'B0009M1O9A']
# A37D1ZP8GBHE38 ['B001OI2Z4Q', 'B00EU9V3YO', 'B003JZU8DC', 'B002MCZJ78', 'B003M0NURK']
# A2PY5ED630H0QJ ['B000CH3IIW', 'B000NOR89Y', 'B0001BVXI6', 'B008U5ZM6E', 'B00APURII2']
# A2ULZRSHXS3HL7 ['B009FILPMU', 'B002CGSYOO', 'B009V71HEQ', 'B00B167X52', 'B00009R9BU']
# A2DF62DP20RIXF ['B003XM1WE0', 'B000GYI76Y', 'B000MQK6BK', 'B00000J1TX', 'B002TTPC4Y']
# A2PMR2PIGWKCQ9 ['B003ES5ZUU', 'B005KFONIU', 'B005LDLP8W', 'B008OEHPKM', 'B00DY2Y28M']
# A3D01HLSUFEZQY ['B000VUIXOO', 'B0018ZDGAC', 'B0019CSVMW', 'B005FRI50K', 'B006G5ZVA2']
# AC1YLEFC9AN5X ['B003MAJMXQ', 'B00K91DB7Y', 'B005LD275M', 'B000TDCJHK', 'B002SZEOLG']
# A2Q7OJTVPIO2XH ['B00017LSPI', 'B00836JHVQ', 'B00EY3YGBS', 'B00BQ8V0EA', 'B0049H15P4']
# AGHZXQL9F94T9 ['B00008OE5G', 'B00009VSIM', 'B0012GQZZU', 'B0006HTPQ2', 'B00008J639']
# A2CPP7BZKOF9TP ['B004G6002M', 'B002VPE1Q6', 'B0092HP3GS', 'B003AVMRQG', 'B006DUDWXI']
# A4GGT6O0GQNV2 ['B00CD8ADKO', 'B00FNPD1OY', 'B00004SY4H', 'B0002GX0ZE', 'B00009NR0R']
# AW6FQE5QRF2LM ['B009USAJCC', 'B005PQTYHE', 'B003Z4G3I6', 'B000WWK16O', 'B0085WN7YQ']
# A1Y051MQ2SVPFI ['B00746LVOM', 'B004J3ZV62', 'B00385XUG0', 'B007I5JT4S', 'B005YW7OLM']
# A186697K4XKXQL ['B0094S35W4', 'B003MAJMXQ', 'B003Y3BFB8', 'B005DOUJL8', 'B000RZNI4S']
# A1MQQEM7W77L62 ['B003ES5ZUU', 'B0097BEF1S', 'B00000J1UQ', 'B00DBDM934', 'B009UEAZ84']
# A3TP31S61PPE3G ['B004R7A9NU', 'B008PQAFR4', 'B006ZBWV0K', 'B003I4FHNA', 'B004GUT1QO']
# A2NX6MFZP8TM6S ['B007R5YDYA', 'B00834SJSK', 'B003LSTD38', 'B000AYJDD6', 'B003WUBIZQ']
# APGQTZZ4ZFPHO ['B009OBCAW2', 'B000U8Y88M', 'B006ZT4VA0', 'B00007E7JU', 'B000LRMS66']
# A3FS3FJPD3RJTD ['B004CLYE8C', 'B00009RDIF', 'B00004T8R2', 'B004BLIQEG', 'B004CLYEH8']
# A15XI2BEGGFEOW ['B0002LEMWE', 'B001ELK2NY', 'B003PJ6QVU', 'B009VV56TY', 'B005HSG3BA']
# A1OO9N1MRNQ7K0 ['B003XIJ566', 'B00026BQJ6', 'B000BRO3PA', 'B003JOPWHK', 'B003XMROKG']
# A1VOFY3QFT9WCG ['B0027AGK3M', 'B004LSNF04', 'B004CADY9I', 'B00CXACR1U', 'B000LDFR8Q']
# ABUE0ALHKWKHC ['B0082E9K7U', 'B006ZBWV0K', 'B0000A2QBP', 'B00FGOTA6K', 'B0051BG48U']
# A2N3JSOIQ6ZNFL ['B00A4ZXE40', 'B003ZM7YTA', 'B001QUA6R0', 'B002POBS46', 'B004HFMNGS']
# A2R1HUYHXV7H18 ['B000N99BBC', 'B004CLYEFK', 'B00ENZRS76', 'B006JH8T3S', 'B00FSA8VQ2']
# ACSX5AIZE3MJ9 ['B00EHZYWGM', 'B00829TIEK', 'B0009STJIW', 'B000V01RLK', 'B003M0NURK']
# A3UXW18DP4WSD6 ['B005QBK5V2', 'B003WGJYCY', 'B009HK30V0', 'B0000AZK4G', 'B0017JY5FE']
# A1FMU4CJLIDHR9 ['B000AP05BO', 'B005CWHZP4', 'B00B7E1D7W', 'B00519RW1U', 'B0036FCW98']
# A9J4UURM4OSDW ['B000UMX7FI', 'B0000X0VCY', 'B0017H4G0A', 'B0096W1OCG', 'B000KFRSG4']
# ABMNX856X89CS ['B00IVFDZBC', 'B00FAYL1YU', 'B00EOI2SYK', 'B00JC5Y6WM', 'B0090A8TWW']
# A1L5TA5UQF7EWE ['B001QUA6RA', 'B000VX6XL6', 'B008R6OPJQ', 'B00A9NE84C', 'B008U3038I']
# A1PAGHECG401K1 ['B000BQ7GW8', 'B0092KRAVQ', 'B000051123', 'B0039BPG4M', 'B00IPNQ3R8']
# A2GMZZ6TDYOHY7 ['B000QUUFRW', 'B007WTAJTO', 'B000CRFOMK', 'B0040JHVC2', 'B00005114Z']
# A19RW25Q6206I3 ['B001BTCSI6', 'B000BY52NK', 'B00081NX5U', 'B001WM73P0', 'B003N2POXK']
# A1NZLRAZJGD99W ['B001OC6DCW', 'B00000JDF6', 'B00158OJ9O', 'B0055XKBW4', 'B0090SLE30']
# AMWL7XIWIPXEZ ['B002G1YPH0', 'B006VCP72W', 'B0000C3GWU', 'B001X017G2', 'B000GQMHBI']
# AHROSV6WJOEGY ['B002V8C3W2', 'B000EPJL1A', 'B000EMWBT2', 'B00005Q5U5', 'B0010YWPZ8']
# A32482Z7XIKDQX ['B00009XVCZ', 'B006QB1RPY', 'B000HPV3RW', 'B009O7YUF6', 'B00829THK0']
# ABAPF3XY1W6JX ['B007VPGL5U', 'B00EU9V3S0', 'B002B3YCQM', 'B001DJ9GOS', 'B00768SBAU']
# A3E68EBGXTWDNP ['B00006JN3G', 'B00079SWNQ', 'B00007EDZG', 'B000BYCKU8', 'B00004TX71']
# A1CST2WUA32GP0 ['B001TH7GUU', 'B000HPV3RW', 'B007SM7O2U', 'B005HXFARS', 'B000Z13844']
# A3MMR2WDKAK0PA ['B006ZH0KVG', 'B00006IJO4', 'B001OMGVII', 'B002AULS7C', 'B004IN85QQ']
# A1Y4EWMUTW73GD ['B001UE8LRY', 'B0052MNIAA', 'B003SPQZSA', 'B000A6TN9I', 'B0028MF260']
# A3J029KBNG5MNP ['B0034CL2ZI', 'B00829TIEK', 'B00829THK0', 'B002C1BHIO', 'B00AWRPIWQ']
# A1R19YYR5OR26T ['B002V88HFE', 'B003DZJQQI', 'B001TH7GUK', 'B001NJ0D0Y', 'B0041Q38NU']
# A2JCJJNY43QQIV ['B0043M668G', 'B00CGWNKVQ', 'B004SKBJYE', 'B00D695GS8', 'B005SNPTRS']
# A2WA8TDCTGUADI ['B000N99BBC', 'B003CFATT2', 'B002YU83YO', 'B0057AVXP4', 'B005CT56F8']
# A2ZWJVKITA32OV ['B00AJHDZSI', 'B006U3O566', 'B004YLCBRG', 'B000HAOVGM', 'B001UQ6F5M']
# ARC5ASW9CUAGP ['B007WTAJTO', 'B00E3W15P0', 'B0010Z294O', 'B005S0XYKK', 'B005FYNSPK']
# AW63IRQWH10GF ['B002TIELEM', 'B0002MH3HO', 'B004F6GJAU', 'B00134LUE2', 'B000VILN6G']
# A1QRST0A3IQIEF ['B002G1YPH0', 'B00004Z5M1', 'B007R67FNA', 'B00FE8MLY6', 'B006YG88QC']
# A2NQMVTQ4PVLL ['B00006B7DA', 'B006H06TVG', 'B004NY9UV4', 'B0091F8EZ8', 'B003N0XDT4']

# %% [markdown]
# ## It is quite conclusively evident that better than recommending a product to a user based on the products' popularity, recommending the identified (*read predicted*) product(s), selected based on understanding the users' past affiliation pattern be more meaningful both for the user and the movement of the product(s).
